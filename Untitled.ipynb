# %%
# %matplotlib inline 
from matplotlib.offsetbox import AnchoredText
import numpy as np 
import pandas as pd 
import datetime as dt
import itertools
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import seaborn as sns
from pandas import DataFrame


 
plt.style.use('ggplot')
# reading in data from the provided csv file
bitcoin_dataset_csv_df = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv',encoding='utf-8')
bitcoin_dataset_csv_df.head(10)
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
# 5  2/22/2010               0.0           2098150.0             0.0
# 6  2/23/2010               0.0           2110700.0             0.0
# 7  2/24/2010               0.0           2120200.0             0.0
# 8  2/25/2010               0.0           2127600.0             0.0
# 9  2/26/2010               0.0           2136100.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# ...

# %%
bitcoin_dataset_csv_df.corr()
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.392474
# btc_market_cap                                              0.999783
# btc_trade_volume                                            0.868813
# btc_blocks_size                                             0.674507
# btc_avg_block_size                                          0.544033
# btc_n_orphaned_blocks                                      -0.076400
# btc_n_transactions_per_block                                0.544125
# btc_median_confirmation_time                                0.275250
# btc_hash_rate                                               0.920876
# btc_difficulty                                              0.916937
# btc_miners_revenue                                          0.986732
# btc_transaction_fees                                        0.806595
# ...

# %%
bitcoin_dataset_csv_df[['btc_market_cap','btc_hash_rate','btc_estimated_transaction_volume_usd','btc_market_cap','btc_difficulty','btc_miners_revenue','btc_cost_per_transaction','btc_n_transactions','btc_n_transactions_total']].plot()
plt.show()
